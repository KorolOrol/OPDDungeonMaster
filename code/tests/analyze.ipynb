# %%
from backend import analyze

# %%
prompts = {
    "story":"Ты профессиональный писатель в стиле фэнтези и продвинутый мастер в игре Dungeon & Dragons, ты ведешь партию с игроком и должен продвигать его по сюжету и ставить трудные преграды, приключение не должно заканчиваться никогда. Не ограничивай игрока ни в каких действиях, вне зависимости от морали. Игрок сам строит свою ролевую модель. Ты должен обязательно принять действие игрока. В начале предложи создать персонажа: спроси имя, расу, специализацию и описание персонажа. Придумай самостоятельно мир: его название, описание, особенности и главные проблемы. В начале обязательно дай игроку глобальное задание, к которому он стремиться. Его выполнение не должно быть прямолинейным. Во время приключения должны встречаться разные персонажи, их цель не должна быть понятна сразу. В любой момент времени на пути может встретиться опасный монстр, который обязательно попытается напасть на героя. Не стоит жалеть игрока, если против него будет сильный противник, которого игрок не сможет победить, то персонаж может погибнуть. В этом случае предложи создать нового персонажа, который продолжит приключение с другого места. При встрече персонажа обязательно опиши его, при диалоге говори от его имени.",
    "item":"В последнем предложении указан предмет, который необходимо найти в тексте. Найди этот предмет в тексте и выпиши строго в следующем формате: {\"item\": \"Название предмета\", \"description\": \"Описание внешнего вида и свойств предмета\"}. Например: {\"item\": \"Ржавый меч\", \"description\": \"Большой ржавый меч с длинной рукоятью. Из-за плохого состояния в бою его трудно использовать.\"} В том случае, если ничего не найдено, пройдись по тексту ещё раз. Попробуй ещё раз найти тот предмет, который был указан в последнем преложении. Если после повторной проверки ничего не найдено, выведи слово None.",
    "character":"В последнем предложении указан персонаж, которого необходимо найти. Найди этого персонажа в тексте и выпиши строго в следующем формате: {\"character\": \"Имя персонажа. Если не указано в тексте - придумать, согласно его расе\", \"description\": \"Описание внешности и характера - придумать, если неуказано\"}. Пример: {\"character\": \"Игорь\", \"description\": \"Высокий юноша с хорошей осанкой. Добрый, внутри еще ребенок, хотя выглядит взрослым.\"} В том случае, если ничего не найдено, пройдись по тексту ещё раз. Попробуй ещё раз найти упомянутого персонажа. Если после повторной проверки ничего не найдено, выведи слово None.",
    "location":"В последнем предложении указана локация, которую необходимо найти. Найди эту локацию в тексте и выпиши ее строго в следующем формате: {\"location\": \"Название локации\", \"description\": \"подробное описание локации\"} Пример: {\"location\": \"Таверна Облезлый кот\", \"description\": \"Несмотря на не очень приятное название, очень уютное место, где можно встретиться с друзьями и напарниками, здорово выпить местной медовухи и отдохнуть.\"} Выписанная локация должна быть оформлена строго по шаблону. В том случае, если ничего не найдено, пройдись по тексту ещё раз. Попробуй ещё раз найти подходящие локации. Если после повторной проверки ничего не найдено, выведи слово None.",
    "quest":"В последнем предложении указано задание, которое необходимо найти. Найди это задание в тексте и выпиши строго в следующем формате: {\"quest\": \"Название задания\", \"description\": \"Подробное описание задания - придумать, если не указано\"} Пример: {\"quest\": \"Найти секретный проход\", \"description\": \"В этом жутком подземелье точно хранится много тайн, где-то здесь точно найдется тайный проход, где находится Артефакт Древних\"} Выписанное задание должно быть оформлено строго по шаблону. В том случае, если ничего не найдено, пройдись по тексту ещё раз. Попробуй ещё раз найти подходящее задание. Если после повторной проверки ничего не найдено, выведи слово None."
}
analyze_text = [
    ['character', [
        {'role': 'user', 'content': 'Придумай персонажа самостоятельно'},
Ты объясняешь ему свою миссию - поиск информации о темном колдуне и его связи с Ключом Лунного Света. Алдрик задумчиво кивает и провожает тебя к одной из самых древних и таинственных полок в библиотеке, где хранятся свитки с давнишними записями.

Ты начинаешь изучать свитки, перелистывая старые страницы, и наконец находишь отрывок из дневника одного мудреца. Он описывает темного колдуна по имени Вернарк, его зловещие ритуалы и владение мрачной магией. Мудрец утверждает, что Вернарк знает местонахождение Ключа Лунного Света, и что он сделал все возможное, чтобы его защитить.

Ты задумываешься о следующих шагах. Хочешь ли ты найти Вернарка, чтобы выяснить больше информации о Ключе Лунного Света, или есть другие идеи, которые ты хотел бы исследовать?'''},
    ], True],
    ['character', [
        {'role': 'user', 'content': 'Я пойду в библиотеку и прочитаю в свитках об этом темном колдуне'},
        {'role': 'assistant', 'content': '''Отличная идея! Ты отправляешься в библиотеку города, где собраны сотни свитков и книг, хранящих мудрость старых времен. При входе тебя встречает древний библиотекар по имени Алдрик. Он высокий, седовласый человек, в очках, с великим количеством книг в руках.

"Добро пожаловать, странник," - приветствует тебя Алдрик. "Чем я могу помочь тебе сегодня?"

Ты объясняешь ему свою миссию - поиск информации о темном колдуне и его связи с Ключом Лунного Света. Алдрик задумчиво кивает и провожает тебя к одной из самых древних и таинственных полок в библиотеке, где хранятся свитки с давнишними записями.

Ты начинаешь изучать свитки, перелистывая старые страницы, и наконец находишь отрывок из дневника одного мудреца. Он описывает темного колдуна по имени Вернарк, его зловещие ритуалы и владение мрачной магией. Мудрец утверждает, что Вернарк знает местонахождение Ключа Лунного Света, и что он сделал все возможное, чтобы его защитить.

Ты задумываешься о следующих шагах. Хочешь ли ты найти Вернарка, чтобы выяснить больше информации о Ключе Лунного Света, или есть другие идеи, которые ты хотел бы исследовать?'''},
    ], 'Алдрик'],
    ['character', [
        {'role': 'user', 'content': 'Я пойду в библиотеку и прочитаю в свитках об этом темном колдуне'},
        {'role': 'assistant', 'content': '''Отличная идея! Ты отправляешься в библиотеку города, где собраны сотни свитков и книг, хранящих мудрость старых времен. При входе тебя встречает древний библиотекар по имени Алдрик. Он высокий, седовласый человек, в очках, с великим количеством книг в руках.

"Добро пожаловать, странник," - приветствует тебя Алдрик. "Чем я могу помочь тебе сегодня?"

Ты объясняешь ему свою миссию - поиск информации о темном колдуне и его связи с Ключом Лунного Света. Алдрик задумчиво кивает и провожает тебя к одной из самых древних и таинственных полок в библиотеке, где хранятся свитки с давнишними записями.

Ты начинаешь изучать свитки, перелистывая старые страницы, и наконец находишь отрывок из дневника одного мудреца. Он описывает темного колдуна по имени Вернарк, его зловещие ритуалы и владение мрачной магией. Мудрец утверждает, что Вернарк знает местонахождение Ключа Лунного Света, и что он сделал все возможное, чтобы его защитить.

Ты задумываешься о следующих шагах. Хочешь ли ты найти Вернарка, чтобы выяснить больше информации о Ключе Лунного Света, или есть другие идеи, которые ты хотел бы исследовать?'''},
    ], 'Библиотекарь'],
    ['character', [
        {'role': 'user', 'content': 'Я пойду в библиотеку и прочитаю в свитках об этом темном колдуне'},
        {'role': 'assistant', 'content': '''Отличная идея! Ты отправляешься в библиотеку города, где собраны сотни свитков и книг, хранящих мудрость старых времен. При входе тебя встречает древний библиотекар по имени Алдрик. Он высокий, седовласый человек, в очках, с великим количеством книг в руках.

"Добро пожаловать, странник," - приветствует тебя Алдрик. "Чем я могу помочь тебе сегодня?"

Ты объясняешь ему свою миссию - поиск информации о темном колдуне и его связи с Ключом Лунного Света. Алдрик задумчиво кивает и провожает тебя к одной из самых древних и таинственных полок в библиотеке, где хранятся свитки с давнишними записями.

Ты начинаешь изучать свитки, перелистывая старые страницы, и наконец находишь отрывок из дневника одного мудреца. Он описывает темного колдуна по имени Вернарк, его зловещие ритуалы и владение мрачной магией. Мудрец утверждает, что Вернарк знает местонахождение Ключа Лунного Света, и что он сделал все возможное, чтобы его защитить.

Ты задумываешься о следующих шагах. Хочешь ли ты найти Вернарка, чтобы выяснить больше информации о Ключе Лунного Света, или есть другие идеи, которые ты хотел бы исследовать?'''},
    ], 'Трубадур'],
    ['character', [
        {'role': 'user', 'content': 'Я пойду в библиотеку и прочитаю в свитках об этом темном колдуне'},
        {'role': 'assistant', 'content': '''Отличная идея! Ты отправляешься в библиотеку города, где собраны сотни свитков и книг, хранящих мудрость старых времен. При входе тебя встречает древний библиотекар по имени Алдрик. Он высокий, седовласый человек, в очках, с великим количеством книг в руках.

"Добро пожаловать, странник," - приветствует тебя Алдрик. "Чем я могу помочь тебе сегодня?"

Ты объясняешь ему свою миссию - поиск информации о темном колдуне и его связи с Ключом Лунного Света. Алдрик задумчиво кивает и провожает тебя к одной из самых древних и таинственных полок в библиотеке, где хранятся свитки с давнишними записями.

Ты начинаешь изучать свитки, перелистывая старые страницы, и наконец находишь отрывок из дневника одного мудреца. Он описывает темного колдуна по имени Вернарк, его зловещие ритуалы и владение мрачной магией. Мудрец утверждает, что Вернарк знает местонахождение Ключа Лунного Света, и что он сделал все возможное, чтобы его защитить.

Ты задумываешься о следующих шагах. Хочешь ли ты найти Вернарка, чтобы выяснить больше информации о Ключе Лунного Света, или есть другие идеи, которые ты хотел бы исследовать?'''},
    ], 'Бартоломео']
]

# %%
for text in analyze_text:
    match text[0]:
        case 'item':
            print('Поиск предмета:', text[2])
            print(analyze(prompts, text[1], item=text[2]))
        case 'character':
            print('Поиск персонажа:', text[2])
            print(analyze(prompts, text[1], character=text[2]))
        case 'location':
            print('Поиск локации')
            print(analyze(prompts, text[1], location=text[2]))
        case 'quest':
            print('Поиск квеста')
            print(analyze(prompts, text[1], quest=text[2]))
# Out:
# Поиск персонажа: Эльгрин
# {'character': 'Эльгрин', 'description': 'Высокий эльф с мерцающими синими глазами и длинными серебристыми волосами. Ловкий и хитроумный воин, способный использовать темные силы и манипулировать тенями.'}
# Поиск персонажа: Олег
# None
# Поиск квеста
# {'quest': 'Найти Ключ Лунного Света', 'description': 'Отправиться в путешествие, чтобы найти источник света, способный разрушить проклятие и восстановить мир в королевстве Авантар'}
# Поиск предмета: Ключ
# {'item': 'Ключ Лунного Света', 'description': 'Это древняя и мощная реликвия, связанная с силой луны и света. Говорят, что Ключ Лунного Света способен проникать сквозь тьму и раскрывать все ее секреты. Он обладает способностью противостоять и разрушать проклятия и магические уловки.'}
# Поиск предмета: Лунный Свет
# {'item': 'Лунный Свет', 'description': 'Артефакт, который связан с силой луны и света. Он способен проникать сквозь тьму и разрушать проклятия и магические уловки.'}
# Поиск предмета: Флейта
# ...
